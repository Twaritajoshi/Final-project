# %%
#You have to design a Food Ordering app for a restaurant.
#The application will have a log-in for admin and users.
#Admin will have the following functionalities:

Add new food items. Food Item will have the following details:
FoodID //It should be generated automatically by the application.
Name
Quantity. For eg, 100ml, 250gm, 4pieces etc
Price
Discount
Stock. Amount left in stock in the restaurant.
Edit food items using FoodID.
View the list of all food items.
Remove a food item from the menu using FoodID.

#The user will have the following functionalities:

Register on the application. Following to be entered for registration:
Full Name
Phone Number
Email
Address
Password
Log in to the application
The user will see 3 options:
Place New Order
Order History
Update Profile
Place New Order: The user can place a new order at the restaurant.
Show list of food. The list item should as follows:
1. Tandoori Chicken (4 pieces) [INR 240]
2. Vegan Burger (1 Piece) [INR 320]
3. Truffle Cake (500gm) [INR 900]
Users should be able to select food by entering an array of numbers. For example, if the user wants to order Vegan Burger and Truffle Cake they should enter [2, 3]
Once the items are selected user should see the list of all the items selected. The user will also get an option to place an order.
Order History should show a list of all the previous orders
Update Profile: the user should be able to update their profile.

# %%
import json
class Restaurent:
    def __init__(self):
        self.food={}  #5---->1: 2: 3: 4:
        self.food_id=len(self.food)+1
        
        
        
#Admin functionaly:
    def food_items(self):
        self.name=input("Enter the food name")
        self.quantity=input("Enter food quantity in:kg,gm,pieces,ml")
        self.price=int(input("Enter food price in:Rs"))
        self.discount=int(input("Enter the food discount in:Rs"))
        self.stock=int(input("Enter food stock: kg"))
        self.item={"name":self.name,"quantity":self.quantity,"price":self.price,"discount":self.discount,"stock":self.stock}
        self.food_id=len(self.food)+1
        self.food[self.food_id]=self.item
        print(self.food)
        with open("Food_items.json","w")as f:
            json.dump(self.food,f)
        print("items added successfully")
        
        
        
        
    def remove_food_items(self):
        food_id=[int(input("Enter the food_id which you want to delete"))]
        print("Remaining items are",self.food)
        with open("Food_items.json","w")as f:
             json.dump(self.food,f) 
        print("Remaining items are",self.food)
        
        
        
        
    def edit_food_items(self):
        food_id=int(input("Enter the food_id which you want to uodate"))
        for i in self.food[food_id]:
            self.food[food_id][i]
            input("Enter the data that you want to update")
        print(self.food)
        with open("food_items.json","w")as f:
             json.dump(self.food,f)  
    print("Food_items updated successfully")
        
        
    def view_food_items(self):
        print("list of all food items")
        for i in self.food:
            print("food_id:",i,"\n***********************************************")
            for j in self.food[i]:
                print(j,self.food[i][j])
        

x=Restaurent()
x=Restaurent()
x=Restaurent()
x.food_items()
print("\n****************")
x.food_items()
print("\n****************")
x.food_items()
print("\n****************")
x.edit_food_items()
print("\n****************")
x.view_food_items()
x.remove_food_items()
# Out:
# Food_items updated successfully
# Enter the food name jilebi
# Enter food quantity in:kg,gm,pieces,ml 50kg
# Enter food price in:Rs 50
# Enter the food discount in:Rs 20
# Enter food stock: kg 50
# {1: {'name': ' jilebi', 'quantity': ' 50kg', 'price': 50, 'discount': 20, 'stock': 50}}
# items added successfully
#
# ****************
# Enter the food name modak
# Enter food quantity in:kg,gm,pieces,ml 50kg
# Enter food price in:Rs 50
# Enter the food discount in:Rs 50
# Enter food stock: kg 50
# {1: {'name': ' jilebi', 'quantity': ' 50kg', 'price': 50, 'discount': 20, 'stock': 50}, 2: {'name': ' modak', 'quantity': ' 50kg', 'price': 50, 'discount': 50, 'stock': 50}}
# items added successfully
#
# ****************
# Enter the food name shahi paneer
# Enter food quantity in:kg,gm,pieces,ml 50kg
# Enter food price in:Rs 150
# Enter the food discount in:Rs 50
# Enter food stock: kg 50
# {1: {'name': ' jilebi', 'quantity': ' 50kg', 'price': 50, 'discount': 20, 'stock': 50}, 2: {'name': ' modak', 'quantity': ' 50kg', 'price': 50, 'discount': 50, 'stock': 50}, 3: {'name': ' shahi paneer', 'quantity': ' 50kg', 'price': 150, 'discount': 50, 'stock': 50}}
# items added successfully
#
# ****************
# Enter the food_id which you want to uodate1
# Enter the data that you want to update veg biryani
# Enter the data that you want to update 50kg
# Enter the data that you want to update 50
# Enter the data that you want to update 50
# Enter the data that you want to update 50
# {1: {'name': ' jilebi', 'quantity': ' 50kg', 'price': 50, 'discount': 20, 'stock': 50}, 2: {'name': ' modak', 'quantity': ' 50kg', 'price': 50, 'discount': 50, 'stock': 50}, 3: {'name': ' shahi paneer', 'quantity': ' 50kg', 'price': 150, 'discount': 50, 'stock': 50}}
#
# ****************
# list of all food items
# food_id: 1
# ***********************************************
# name  jilebi
# quantity  50kg
# price 50
# discount 20
# stock 50
# food_id: 2
# ***********************************************
# name  modak
# quantity  50kg
# price 50
# discount 50
# stock 50
# food_id: 3
# ***********************************************
# name  shahi paneer
# quantity  50kg
# price 150
# discount 50
# stock 50
# Enter the food_id which you want to delete1
# Remaining items are {1: {'name': ' jilebi', 'quantity': ' 50kg', 'price': 50, 'discount': 20, 'stock': 50}, 2: {'name': ' modak', 'quantity': ' 50kg', 'price': 50, 'discount': 50, 'stock': 50}, 3: {'name': ' shahi paneer', 'quantity': ' 50kg', 'price': 150, 'discount': 50, 'stock': 50}}
# Remaining items are {1: {'name': ' jilebi', 'quantity': ' 50kg', 'price': 50, 'discount': 20, 'stock': 50}, 2: {'name': ' modak', 'quantity': ' 50kg', 'price': 50, 'discount': 50, 'stock': 50}, 3: {'name': ' shahi paneer', 'quantity': ' 50kg', 'price': 150, 'discount': 50, 'stock': 50}}

# %%
#User Functionality
class user:
    def _init_(self):
        self.user_info={}
        self.user_id=len(self.user_info)+1
    def Register_user_info(self):
        self.name=input("Enter your name ")
        self.mob_no=int(input("Enter your Mobile number "))
        self.email=input("Enter your Email ")
        self.address=input("Enter your Address ")
        self.password=input("Enter your Password ")
        print("You have Registered successfully")
        self.items={'name':self.name,"mob_no":self.mob_no,"Email":self.email,"Address":self.address,"password":self.password}
        self.Register_user_info=self.items
        self.user_id=len(self.Register_user_info)+1
        print(self.items)
        self.user_id=len(self.Register_user_info)+1
    
    def login(self):
            print("For logging\n")
            self.user_email=input("Enter your email")
            while True:
                 for i in self.items:
                    for j in self.items[i]:
                        if self.items['Email']==self.user_email:
                            k=0
                            while k<3:
                                self.user_password=input("Enter your Password ")
                                if self.items['password']==self.user_password:
                                    print("You have successfully logged ")
                                    print("\n**Welcome to Our Restaurent**")
                                    return   
                                else:
                                    print("Password is incorrect, try again")
                                    k=k+1
                                    print("You have tried 3 attempts, Please try after sometimes!!!")
                                    break
                                    print("invalid credential")
                                    return
                                
                                
                                
    def place_order(self):
        self.order=[]
        print("""List of food is
        1. Tandoori Chicken(4 pieces)[INR 240]
        2. Vegan Burger (1 Piece) [INR 320]
        3. Truffle Cake (500gm) [INR 900])""")
        for i in range(3):
            self.food=input("Enter which order you want to place ")
            if self.food=="1":
                self.order.append("Tandoori chicken")
                if self.food=="2":
                    self.order.append("Vegan Burger")
                    if self.food=="3":
                        self.order.append("Truffle Cake")
                        print("If you don't want another order just tab Enter")
                        print("\nplace order list is ",self.order)
                                                    
                                                    
    def order_history(self):
        print("\nYour order history is ")
        for i in self.order:
            print(i)
                                        
                                        
                                        
    def update_profile(self):
        a=int(input("Enter your user id"))
        for i in self.items:
            self.items[i]=input(f"Enter the {i} that you want to update ")
            print("\n",self.items)
       
       
x=user()
x.Register_user_info()
print("\n******************************************")

x.login()
print("\n******************************************")
x.place_order()
print("\n******************************************")
x.order_history()
print("\n******************************************")
x.update_profile()
print("\n******************************************")
# Out:
# Enter your name Twarita
# Enter your Mobile number 9382714644
# Enter your Email twarita25
# Enter your Address Chandgad
# Enter your Password twara
# You have Registered successfully
# {'name': 'Twarita', 'mob_no': 9382714644, 'Email': 'twarita25', 'Address': 'Chandgad', 'password': 'twara'}
#
# ******************************************
# For logging
#
# Enter your emailtwarita25
# Enter your Password twara
# You have successfully logged
#
# **Welcome to Our Restaurent**
#
# ******************************************
# List of food is
#         1. Tandoori Chicken(4 pieces)[INR 240]
#         2. Vegan Burger (1 Piece) [INR 320]
#         3. Truffle Cake (500gm) [INR 900])
# Enter which order you want to place 2
# Enter which order you want to place 3
# Enter which order you want to place 2
#
# ******************************************
#
# Your order history is
#
# ******************************************
# Enter your user id1
# Enter the name that you want to update twarita
#
#  {'name': 'twarita', 'mob_no': 9382714644, 'Email': 'twarita25', 'Address': 'Chandgad', 'password': 'twara'}
# Enter the mob_no that you want to update 9322899029
#
#  {'name': 'twarita', 'mob_no': '9322899029', 'Email': 'twarita25', 'Address': 'Chandgad', 'password': 'twara'}
# Enter the Email that you want to update twaritaj25
#
#  {'name': 'twarita', 'mob_no': '9322899029', 'Email': 'twaritaj25', 'Address': 'Chandgad', 'password': 'twara'}
# Enter the Address that you want to update Hera
#
#  {'name': 'twarita', 'mob_no': '9322899029', 'Email': 'twaritaj25', 'Address': 'Hera', 'password': 'twara'}
# Enter the password that you want to update twaru
#
#  {'name': 'twarita', 'mob_no': '9322899029', 'Email': 'twaritaj25', 'Address': 'Hera', 'password': 'twaru'}
#
# ******************************************
